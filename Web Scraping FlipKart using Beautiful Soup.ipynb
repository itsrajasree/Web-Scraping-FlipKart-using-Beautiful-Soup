# %% [markdown]
# # Web Scraping FlipKart using Beautiful Soup

# %% [markdown]
# ###### The details of Samsung mobile phones from flipkart are scraped using Beautiful Soup

# %% [markdown]
# Importing all necessary variables

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# The URL of the site is passed to variable response

# %%
response = requests.get("https://www.flipkart.com/search?q=samsung%20touch%20mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %% [markdown]
# Checking for the status code. If code is 200, no error; go forward for the scraping

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Parsing Html

# %% [markdown]
# Parsing html using Beautiful Soup and viewing the content in the html file.
# prettify() method automatically alligns the data and improves readability.

# %%
soup = BeautifulSoup(response.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.219133.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
#    <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#    <!-- Appple Touch Icons -->
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#    <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/>
#    <!-- Twitter Meta Data -->
#    <meta content="app" name="twitter:card"/>
#    <meta content="@flipkart" name="twitter:site"/>
#    <meta content="@flipkart" name="twitter:creator"/>
#    <meta content="Samsung Touch Mobiles - Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="twitter:title"/>
#    <meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/>
#    <meta content="in" name="twitter:app:country"/>
#    <meta content="Flipkart" name="al:ios:app_name"/>
#    <meta content="742044692" name="al:ios:app_store_id"/>
#    <meta content="Flipkart" name="twitter:app:name:iphone"/>
#    <meta content="742044692" name="twitter:app:id:iphone"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/>
#    <meta content="Flipkart" name="twitter:app:name:ipad"/>
#    <meta content="742044692" name="twitter:app:id:ipad"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/>
#    <meta content="Flipkart" name="twitter:app:name:googleplay"/>
#    <meta content="com.flipkart.android" name="twitter:app:id:googleplay"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/>
#    <style>
#     #container {
# 			height: 100%;
# 		}
#    </style>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/runtime.89e976e7.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/vendor.chunk.b43a1753.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app_modules.chunk.c43c26ed.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app_common.chunk.6ee4f835.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app.chunk.2b070c8b.js">
#    </script>
#    <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/MultiWidgetBase.chunk.9150f5.css" rel="stylesheet"/>
#    <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/Browse.chunk.63155a.css" rel="stylesheet"/>
#    <title>
#     Samsung Touch Mobiles - Buy Products Online at Best Price in India - All Categories | Flipkart.com
#    </title>
#    <meta content="Samsung Touch Mobiles - Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="og_title" property="og:title">
#     <meta content="Samsung Touch Mobiles" name="Keywords">
#      <meta content="Samsung Touch Mobiles - Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" name="Description">
#       <meta content="Samsung Touch Mobiles - Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" property="og:description">
#        <meta content="noindex" name="robots">
#         <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01">
#          <!--[if IE 9 ]>
# 	<script nonce="10680836730608612107">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
#          <!--[if !IE]><!-->
#          <script nonce="10680836730608612107">
#           if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}
#          </script>
#          <!--<![endif]-->
#          <script id="jsonLD" nonce="10680836730608612107" type="application/ld+json">
#           {"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.flipkart.com/samsung-galaxy-m31-ocean-blue-128-gb/p/itm1d7db8f4e2fec?pid=MOBFPNPSZYJXQZCM&lid=LSTMOBFPNPSZYJXQZCMDFOR1Z&marketplace=FLIPKART","name":"Samsung Galaxy M31 (Ocean Blue, 128 GB)"},{"@type":"ListItem","position":2,"url":"https://www.flipkart.com/samsung-galaxy-m01-blue-32-gb/p/itmc068b26305a0d?pid=MOBFRZZHMHQVNDFA&lid=LSTMOBFRZZHMHQVNDFA778QEJ&marketplace=FLIPKART","name":"Samsung Galaxy M01 (Blue, 32 GB)"},{"@type":"ListItem","position":3,"url":"https://www.flipkart.com/samsung-galaxy-m21-raven-black-64-gb/p/itm3042c3639f5af?pid=MOBFSF867ET7DDMZ&lid=LSTMOBFSF867ET7DDMZCGQLQ7&marketplace=FLIPKART","name":"Samsung Galaxy M21 (Raven Black, 64 GB)"},{"@type":"ListItem","position":4,"url":"https://www.flipkart.com/samsung-galaxy-m11-metallic-blue-32-gb/p/itme875f568bb05b?pid=MOBFRZZHHUZTTYCZ&lid=LSTMOBFRZZHHUZTTYCZJDGM2H&marketplace=FLIPKART","name":"Samsung Galaxy M11 (Metallic Blue, 32 GB)"},{"@type":"ListItem","position":5,"url":"https://www.flipkart.com/samsung-galaxy-a21s-black-64-gb/p/itm3f1fa3caa5ac6?pid=MOBFSFMJZVFVNDAG&lid=LSTMOBFSFMJZVFVNDAGCQVA7S&marketplace=FLIPKART","name":"Samsung Galaxy A21s (Black, 64 GB)"},{"@type":"ListItem","position":6,"url":"https://www.flipkart.com/samsung-galaxy-a21s-blue-64-gb/p/itmb0bd07306db00?pid=MOBFSFMJJBTXPTRR&lid=LSTMOBFSFMJJBTXPTRR4BE1KX&marketplace=FLIPKART","name":"Samsung Galaxy A21s (Blue, 64 GB)"},{"@type":"ListItem","position":7,"url":"https://www.flipkart.com/samsung-galaxy-a31-prism-crush-black-128-gb/p/itm629da21d10cba?pid=MOBFRZZHWPX3YG2J&lid=LSTMOBFRZZHWPX3YG2JP5DVNQ&marketplace=FLIPKART","name":"Samsung Galaxy A31 (Prism Crush Black, 128 GB)"},{"@type":"ListItem","position":8,"url":"https://www.flipkart.com/samsung-galaxy-a51-prism-crush-blue-128-gb/p/itm821baad86fbc5?pid=MOBFS72HDJXVHAYP&lid=LSTMOBFS72HDJXVHAYPN2FL91&marketplace=FLIPKART","name":"Samsung Galaxy A51 (Prism Crush Blue, 128 GB)"},{"@type":"ListItem","position":9,"url":"https://www.flipkart.com/samsung-galaxy-a51-prism-crush-black-128-gb/p/itmabb4d1b812551?pid=MOBFS72HZ9A2FNZP&lid=LSTMOBFS72HZ9A2FNZPPCHXAQ&marketplace=FLIPKART","name":"Samsung Galaxy A51 (Prism Crush Black, 128 GB)"},{"@type":"ListItem","position":10,"url":"https://www.flipkart.com/samsung-galaxy-a21s-white-64-gb/p/itm7c9ebb90b5080?pid=MOBFSFMJKQPBWJFB&lid=LSTMOBFSFMJKQPBWJFBBNW6ZF&marketplace=FLIPKART","name":"Samsung Galaxy A21s (White, 64 GB)"}]}
#          </script>
#          <script nonce="10680836730608612107">
#           !function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#          </script>
#          <script nonce="10680836730608612107">
#           if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#          </script>
#          <link href="https://www.flipkart.com/search?q=samsung+touch+mobiles&amp;otracker=search&amp;otracker1=search&amp;marketplace=FLIPKART&amp;as-show=on&amp;as=off&amp;page=2" id="next-page-link-tag" rel="next"/>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body>
#   <div id="container">
#    <div data-reactroot="">
#     <div class="_3ybBIU">
#      <div class="_1tz-RS">
#       <div class="_1S7OK2">
#       </div>
#       <div class="_3pNZKl">
#        <div class="_1T-JyI">
#         <div class="_3dGepu">
#          <a href="/">
#           <img alt="Flipkart" class="_1e_EAo" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png" title="Flipkart" width="75"/>
#          </a>
#          <a class="_33x-Wq" href="/plus">
#           Explore
#           <!-- -->
#           <span class="_2Ky4Ru">
#            Plus
#           </span>
#           <img src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/plus_b13a8b.png" width="10"/>
#          </a>
#         </div>
#        </div>
#        <div class="Y5-ZPI">
#         <form action="/search" class="_1WMLwI header-form-search" method="GET">
#          <div class="col-12-12 _2tVp4j">
#           <div class="O8ZS_U">
#            <input autocomplete="off" class="LM6RPg" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="samsung touch mobiles"/>
#           </div>
#           <button class="vh79eN" type="submit">
#            <svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
#             <g fill="#2874F1" fill-rule="evenodd">
#              <path class="_2BhAHa" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203">
#              </path>
#              <path class="_2BhAHa" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467">
#              </path>
#             </g>
#            </svg>
#           </button>
#           <input name="otracker" type="hidden" value="search"/>
#           <input name="otracker1" type="hidden" value="search"/>
#           <input name="marketplace" type="hidden" value="FLIPKART"/>
#           <input name="as-show" type="hidden" value="off"/>
#           <input name="as" type="hidden" value="off"/>
#          </div>
#          <ul class="col-12-12 _1PBbw8">
#          </ul>
#         </form>
#        </div>
#        <div class="_1jA3uo _34niwY">
#         <div class="dHGf8H">
#          <div class="_1jcwFN _3dmQRh">
#           <div>
#            <a class="_3Ep39l" href="/account/login?ret=/search%3Fq%3Dsamsung%2520touch%2520mobiles%26otracker%3Dsearch%26otracker1%3Dsearch%26marketplace%3DFLIPKART%26as-show%3Don%26as%3Doff">
#             Login
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="_1jA3uo">
#         <div class="dHGf8H">
#          <div class="_1jcwFN _3dmQRh">
#           <div>
#            <div class="_2aUbKa">
#             <!-- -->
#             More
#             <!-- -->
#            </div>
#           </div>
#          </div>
#          <svg class="_34Yjv1" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg">
#           <path class="_14jSvk" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#           </path>
#          </svg>
#         </div>
#        </div>
#        <div class="_1jA3uo">
#         <div class="_1jcwFN">
#          <div class="_3K4_9Q">
#           <a class="_3ko_Ud" href="/viewcart?otracker=Cart_Icon_Click">
#            <svg class="_2fcmoV" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg">
#             <path class="_2JpNOH" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff">
#             </path>
#            </svg>
#            <span>
#             Cart
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="_1S7OK2">
#       </div>
#      </div>
#      <div class="_2hlh_L">
#      </div>
#     </div>
#     <div class="zi6sUf">
#     </div>
#     <div class="t-0M7P _2doH3V">
#      <div class="_1VV5Cf _1QHAXj">
#       <div class="_1SFos- _14bj8B" style="transform:scaleX(0)">
#       </div>
#      </div>
#      <div class="_3e7xtJ">
#       <div class="_1HmYoV hCUpcT">
#        <div class="_1HmYoV _35HD7C" style="flex:0 0 280px;max-width:280px;padding:0px 10px 0px 0px">
#         <div class="_1HmYoV _35HD7C col-12-12">
#          <div class="bhgxx2 col-12-12">
#           <div class="_1YuAuf">
#            <section class="xeGmCJ D_NGuZ">
#             <div class="_1iMC4O">
#              <div class="D0YrLF">
#               <span>
#                Filters
#               </span>
#              </div>
#             </div>
#            </section>
#            <div class="_1AsMpB">
#             <section class="_3aoPnm">
#              <div class="_1-5MDT">
#               <span>
#                CATEGORIES
#               </span>
#              </div>
#              <div>
#               <div class="sUG0yY">
#                <span>
#                 <svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg">
#                  <path class="zTtNVt" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                  </path>
#                 </svg>
#                </span>
#                <a class="_3O_Sek _32ZSYo" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung+touch+mobiles&amp;otracker=categorytree" title="Mobiles &amp; Accessories">
#                 Mobiles &amp; Accessories
#                </a>
#               </div>
#              </div>
#              <div>
#               <div class="sUG0yY">
#                <span>
#                 <svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg">
#                  <path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                  </path>
#                 </svg>
#                </span>
#                <a class="_3XS1AH _32ZSYo" href="/mobiles/pr?sid=tyy,4io&amp;q=samsung+touch+mobiles&amp;otracker=categorytree" title="Mobiles">
#                 Mobiles
#                </a>
#               </div>
#              </div>
#             </section>
#            </div>
#            <section class="_1MCcAi D_NGuZ">
#             <div class="_1IqaqM _1iMC4O">
#              <div class="_2Bzspk D0YrLF">
#               <span>
#                Price
#               </span>
#              </div>
#             </div>
#             <div class="_1zXsFA">
#              <div class="_23Eu_p">
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#              </div>
#             </div>
#             <div class="_1A0dov">
#              <div class="gl5Kwg">
#               <div class="_3G9WVX oVjMho">
#                <div class="_3aQU3C">
#                </div>
#               </div>
#               <div class="_3G9WVX _2N3EuE">
#                <div class="_3aQU3C">
#                </div>
#               </div>
#               <div class="_3QFE_k">
#               </div>
#               <div class="_3QFE_k _3bwhLT">
#               </div>
#              </div>
#              <div class="UkModz">
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:0px">
#                .
#               </div>
#              </div>
#             </div>
#             <div class="_3Uy12X">
#              <div class="_1qKb_B">
#               <select class="fPjUPw">
#                <option class="OMc8Rd" selected="" value="Min">
#                 Min
#                </option>
#                <option class="OMc8Rd" value="2000">
#                 ₹2000
#                </option>
#                <option class="OMc8Rd" value="4000">
#                 ₹4000
#                </option>
#                <option class="OMc8Rd" value="7000">
#                 ₹7000
#                </option>
#                <option class="OMc8Rd" value="10000">
#                 ₹10000
#                </option>
#                <option class="OMc8Rd" value="13000">
#                 ₹13000
#                </option>
#                <option class="OMc8Rd" value="16000">
#                 ₹16000
#                </option>
#                <option class="OMc8Rd" value="20000">
#                 ₹20000
#                </option>
#                <option class="OMc8Rd" value="25000">
#                 ₹25000
#                </option>
#                <option class="OMc8Rd" value="30000">
#                 ₹30000
#                </option>
#                <option class="OMc8Rd" value="50000">
#                 ₹50000
#                </option>
#               </select>
#              </div>
#              <div class="_2LchWD">
#               to
#              </div>
#              <div class="_1YoBfV">
#               <select class="fPjUPw">
#                <option class="OMc8Rd" value="2000">
#                 ₹2000
#                </option>
#                <option class="OMc8Rd" value="4000">
#                 ₹4000
#                </option>
#                <option class="OMc8Rd" value="7000">
#                 ₹7000
#                </option>
#                <option class="OMc8Rd" value="10000">
#                 ₹10000
#                </option>
#                <option class="OMc8Rd" value="13000">
#                 ₹13000
#                </option>
#                <option class="OMc8Rd" value="16000">
#                 ₹16000
#                </option>
#                <option class="OMc8Rd" value="20000">
#                 ₹20000
#                </option>
#                <option class="OMc8Rd" value="25000">
#                 ₹25000
#                </option>
#                <option class="OMc8Rd" value="30000">
#                 ₹30000
#                </option>
#                <option class="OMc8Rd" value="50000">
#                 ₹50000
#                </option>
#                <option class="OMc8Rd" selected="" value="Max">
#                 ₹50000+
#                </option>
#               </select>
#              </div>
#             </div>
#            </section>
#            <section class="D_NGuZ _1KDdN8">
#             <div class="_2kFyHg _1_fxb2">
#              <label>
#               <input class="_3uUUD5" readonly="" type="checkbox"/>
#               <div class="_1p7h2j _2irnD_">
#               </div>
#               <div class="_1GEhLw">
#                <div class="_2rIV_l">
#                 <img class="_2rIV_l" height="21" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png"/>
#                </div>
#               </div>
#              </label>
#             </div>
#             <div class="_20yN1P">
#              <span class="question">
#               ?
#              </span>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               RAM
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="6 GB &amp; Above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    6 GB &amp; Above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="4 GB">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    4 GB
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="3 GB">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    3 GB
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="2 GB">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    2 GB
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="1 GB">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    1 GB
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="512 MB - 1 GB">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    512 MB - 1 GB
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Less than 512 MB">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Less than 512 MB
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Brand
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="Samsung">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Samsung
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Customer Ratings
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="4★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    4★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="3★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    3★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="2★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    2★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="1★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    1★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Internal Storage
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Battery Capacity
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Operating System
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Network Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Screen Size
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Sim Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Primary Camera
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Secondary Camera
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Offers
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="Bank Offer">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Bank Offer
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Buy More, Save More">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Buy More, Save More
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Exchange Offer">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Exchange Offer
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="No Cost EMI">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    No Cost EMI
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Special Price">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Special Price
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Processor Brand
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Speciality
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Resolution Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Operating System Version Name
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Availability
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Clock Speed
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Features
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Number of Cores
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Budget
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#           </div>
#          </div>
#          <div class="bhgxx2 col-12-12">
#           <a class="_2cPh2h" href="/buying-guide/mobiles?sid=tyy,4io&amp;otracker=bg_from_browse_lhs" title="Buying Guide">
#            <div>
#             <span>
#              Need help?
#             </span>
#            </div>
#            <div class="_3OzbwH">
#             <span>
#              Help me decide
#             </span>
#             <svg class="_1fiSL1" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#              <path class="_3fPZ07" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#              </path>
#             </svg>
#            </div>
#            <img alt="Buying Guide" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_48642c.png"/>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="_1HmYoV _35HD7C" style="flex-grow:1;overflow:auto">
#         <div class="_1HmYoV hCUpcT col-12-12" style="background-color:#ffffff;align-items:flex-end">
#          <div class="bhgxx2" style="flex-grow:1;overflow:auto">
#           <div class="_3UEiDE">
#            <div class="_1joEet">
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/">
#               Home
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">
#               Mobiles &amp; Accessories
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">
#               Mobiles
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </div>
#            <span class="_2yAnYN">
#             Showing 1 – 24 of 416 results for "
#             <span>
#              samsung touch mobiles
#             </span>
#             "
#            </span>
#            <div class="_3ywJNQ">
#             <span class="_3YmFT8">
#              Sort By
#             </span>
#             <div class="_1xHtJz xufquN">
#              Relevance
#             </div>
#             <div class="_1xHtJz">
#              Popularity
#             </div>
#             <div class="_1xHtJz">
#              Price -- Low to High
#             </div>
#             <div class="_1xHtJz">
#              Price -- High to Low
#             </div>
#             <div class="_1xHtJz">
#              Newest First
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="bhgxx2 col-12-12">
#          <div class="_3O0U0u">
#           <div data-id="MOBFPNPSZYJXQZCM" style="width:100%">
#            <div class="_1UoZlX">
#             <a class="_31qSD5" href="/samsung-galaxy-m31-ocean-blue-128-gb/p/itm1d7db8f4e2fec?pid=MOBFPNPSZYJXQZCM&amp;lid=LSTMOBFPNPSZYJXQZCMDFOR1Z&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=55697352-c0d9-4b0b-9369-35b71070aaed.MOBFPNPSZYJXQZCM.SEARCH&amp;ssid=vjjnvd5ne80000001598630178594&amp;qH=69d68205ca2b248b" rel="noopener noreferrer" target="_blank">
#              <div class="_3SQWE6">
#               <div class="_1OCn9C">
#                <div>
#                 <div class="_3BTv9X" style="height:200px;width:200px">
#                  <img alt="Samsung Galaxy M31 (Ocean Blue, 128 GB)" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
#                 </div>
#                </div>
#               </div>
#               <div class="_2lesQu">
#                <div class="_1O_CiZ">
#                 <span class="_1iHA1p">
#                  <div class="_2kFyHg">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                   </label>
#                  </div>
#                 </span>
#                 <label class="_10TB-Q">
#                  <span>
#                   Add to Compare
#                  </span>
#                 </label>
#                </div>
#               </div>
#               <div class="_3gDSOa _32A6AP">
#                <div class="DsQ2eg">
#                 <svg class="_2oLiqr" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                  <path class="_35Y7Yo" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                  </path>
#                 </svg>
#                </div>
#               </div>
#              </div>
#              <div class="_1-2Iqu row">
#               <div class="col col-7-12">
#                <div class="_3wU53n">
#                 Samsung Galaxy M31 (Ocean Blue, 128 GB)
#                </div>
#                <div class="niH0FQ">
#                 <span class="_2_KrJI" id="productRating_LSTMOBFPNPSZYJXQZCMDFOR1Z_MOBFPNPSZYJXQZCM_">
#                  <div class="hGSR34">
#                   4.4
#                   <img class="_2lQ_WZ" src="..."/>
#                  </div>
#                 </span>
#                 <span class="_38sUEc">
#                  <span>
#                   <span>
#                    1,297 Ratings
#                   </span>
#                   <span class="_1VpSqZ">
#                    &amp;
#                   </span>
#                   <span>
#                    126 Reviews
#                   </span>
#                  </span>
#                 </span>
#                </div>
#                <div class="_3ULzGw">
#                 <ul class="vFw0gD">
#                  <li class="tVe95H">
#                   6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
#                  </li>
#                  <li class="tVe95H">
#                   16.26 cm (6.4 inch) Full HD+ Display
#                  </li>
#                  <li class="tVe95H">
#                   64MP + 8MP + 5MP + 5MP | 32MP Front Camera
#                  </li>
#                  <li class="tVe95H">
#                   6000 mAh Battery
#                  </li>
#                  <li class="tVe95H">
#                   Samsung Exynos 9 Octa 9611 Processor
#                  </li>
#                  <li class="tVe95H">
#                   1 year
#                  </li>
#                 </ul>
# ...
#                <g>
#                 <circle cx="6" cy="6" fill="#878787" r="6">
#                 </circle>
#                 <path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5">
#                 </path>
#                </g>
#               </svg>
#               <p class="_19inI8" id="review-b9b0c303-90ff-40f1-82c4-bd7053ec0fd2">
#                <span>
#                 Certified Buyer
#                </span>
#               </p>
#               <p class="_3LYOAd">
#                27 days ago
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="_2Otlc1">
#           <div class="_1gH7KG">
#            Recent Review
#           </div>
#           <div class="col">
#            <div class="col _390CkK jc3RMt">
#             <div class="row">
#              <div class="hGSR34 E_uFuv">
#               4
#               <img class="_2lQ_WZ" src="..."/>
#              </div>
#              <p class="_2xg6Ul">
#               Very Good
#              </p>
#             </div>
#             <div class="row">
#              <div class="qwjRop">
#               <div>
#                <div class="">
#                 Nice phone from the trusted brand
#                </div>
#                <span class="_2jRR3v">
#                 <span>
#                  Read full review
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#             <div class="row _2pclJg">
#              <div class="row">
#               <p class="_3LYOAd _3sxSiS">
#                Ashish  Singhal
#               </p>
#               <svg class="_3Zp_NJ" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg">
#                <g>
#                 <circle cx="6" cy="6" fill="#878787" r="6">
#                 </circle>
#                 <path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5">
#                 </path>
#                </g>
#               </svg>
#               <p class="_19inI8" id="review-596930b6-aa20-4abe-be74-b1c492ba8f59">
#                <span>
#                 Certified Buyer
#                </span>
#               </p>
#               <p class="_3LYOAd">
#                Today
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="bhgxx2 col-12-12">
#       </div>
#      </div>
#     </div>
#     <footer class="HJlsB9">
#      <div class="TW4owM">
#       <div class="row">
#        <div class="col gu12 _2-C188">
#        </div>
#       </div>
#       <div>
#        <div class="_2NHqR1 row">
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           ABOUT
#          </div>
#          <a class="_287FRX" href="/helpcentre?otracker=undefined_footer_navlinks">
#           Contact Us
#          </a>
#          <a class="_287FRX" href="/about-us?otracker=undefined_footer_navlinks">
#           About Us
#          </a>
#          <a class="_287FRX" href="https://www.flipkartcareers.com/?otracker=undefined_footer_navlinks">
#           Careers
#          </a>
#          <a class="_287FRX" href="http://stories.flipkart.com/?otracker=undefined_footer_navlinks">
#           Flipkart Stories
#          </a>
#          <a class="_287FRX" href="/s/press?otracker=undefined_footer_navlinks">
#           Press
#          </a>
#          <a class="_287FRX" href="https://www.flipkartwholesale.com/?otracker=undefined_footer_navlinks" target="_blank">
#           Flipkart Wholesale
#          </a>
#         </div>
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           HELP
#          </div>
#          <a class="_287FRX" href="/pages/payments">
#           Payments
#          </a>
#          <a class="_287FRX" href="/pages/shipping">
#           Shipping
#          </a>
#          <a class="_287FRX" href="/helpcentre?catalog=55c9c6edb000002e002c1701&amp;view=CATALOG">
#           Cancellation &amp; Returns
#          </a>
#          <a class="_287FRX" href="/helpcentre?catalog=55c9c8e2b0000023002c1702&amp;view=CATALOG">
#           FAQ
#          </a>
#          <a class="_287FRX" href="https://seller.flipkart.com/fiv?otracker=undefined_footer_navlinks">
#           Report Infringement
#          </a>
#         </div>
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           POLICY
#          </div>
#          <a class="_287FRX" href="/pages/returnpolicy?otracker=undefined_footer_navlinks">
#           Return Policy
#          </a>
#          <a class="_287FRX" href="/pages/terms?otracker=undefined_footer_navlinks">
#           Terms Of Use
#          </a>
#          <a class="_287FRX" href="/pages/paymentsecurity?otracker=undefined_footer_navlinks">
#           Security
#          </a>
#          <a class="_287FRX" href="/pages/privacypolicy?otracker=undefined_footer_navlinks">
#           Privacy
#          </a>
#          <a class="_287FRX" href="/sitemap?otracker=undefined_footer_navlinks">
#           Sitemap
#          </a>
#          <a class="_287FRX" href="/pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks">
#           EPR Compliance
#          </a>
#         </div>
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           SOCIAL
#          </div>
#          <a class="_287FRX" href="https://www.facebook.com/flipkart">
#           Facebook
#          </a>
#          <a class="_287FRX" href="https://www.twitter.com/flipkart">
#           Twitter
#          </a>
#          <a class="_287FRX" href="https://www.youtube.com/flipkart">
#           YouTube
#          </a>
#         </div>
#         <div class="_3qd5C5 address">
#          <div class="_38DIp6">
#           <div class="_18wTSA">
#            <span>
#             Mail Us:
#            </span>
#           </div>
#           <div class="_2V3TtE">
#            <div class="_3Lv0nZ">
#             <div class="_3aS5mM _2V3TtE">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
#              <p>
#               Clove Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Bengaluru, 560103,
#              </p>
#              <p>
#               Karnataka, India
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="_3qd5C5 address">
#          <div class="m6ABEi">
#           <div class="_18wTSA">
#            <span>
#             Registered Office Address:
#            </span>
#           </div>
#           <div class="_2V3TtE">
#            <div class="_3Lv0nZ">
#             <div class="_3aS5mM _2V3TtE">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
#              <p>
#               Clove Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Bengaluru, 560103,
#              </p>
#              <p>
#               Karnataka, India
#              </p>
#              <p>
#               CIN : U51109KA2012PTC066107
#              </p>
#              <p>
#               Telephone:
#               <a href="tel:18002089898">
#                1800 208 9898
#               </a>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div>
#         <div class="_1DXv5h">
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect">
#            <span class="_1Dwg_s">
#             Sell On Flipkart
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="https://brands.flipkart.com">
#            <span class="_1Dwg_s">
#             Advertise
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="/the-gift-card-store?otracker=undefined_footer_footer_navlinks">
#            <span class="_1Dwg_s">
#             Gift Cards
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="/helpcentre?otracker=undefined_footer_footer_navlinks">
#            <span class="_1Dwg_s">
#             Help Center
#            </span>
#           </a>
#          </div>
#          <span class="_2tFDQF">
#           © 2007-
#           <!-- -->
#           2020
#           <!-- -->
#           <span>
#            Flipkart.com
#           </span>
#          </span>
#          <img src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/payment-method_b3ab24.svg"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="_16c-eX _16DdHx">
#      <div class="kxUxS5">
#       <svg class="j43Uvy" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#        <path class="_14b0BE" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#        </path>
#       </svg>
#       <span>
#        Back to top
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script nonce="10680836730608612107" type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }
#   </script>
#   <script id="is_script" nonce="10680836730608612107">
#    window.__INITIAL_STATE__ = {"abExperiments":{"bucket[]":{"value":"thanosAttributeMobile","abId":"3517965a"},"trackingId":{"value":"thanosAttributeMobile","abId":"3517965a"},"babyc-produ-236fc":{"value":"clone-produ-a9f9d","abId":"491f81be"},"toysa-produ-ad2d5":{"value":"clone-produ-bc3f3","abId":"491f81be"},"ppv4l-produ-c7a3a":{"value":"clone-produ-214d6","abId":"491f81be"},"produ-produ-a044c":{"value":"clone-produ-577d2","abId":"491f81be"},"elect-produ-884e6":{"value":"clone-produ-f494f","abId":"491f81be"},"ppv4l-produ-f0df7":{"value":"clone-produ-78aa3","abId":"491f81be"},"foodp-produ-7a20a":{"value":"clone-produ-989b9","abId":"491f81be"},"watch-produ-7ce10":{"value":"clone-produ-d0103","abId":"491f81be"},"ppv4t-produ-p0001":{"value":"clone-produ-23098","abId":"491f81be"},"ppv4l-produ-23a81":{"value":"clone-produ-8eb5c","abId":"491f81be"},"homep-produ-198f5":{"value":"clone-produ-ed1c7","abId":"491f81be"},"ppv4t-produ-p0004":{"value":"clone-produ-7d078","abId":"491f81be"},"homel-produ-fca8b":{"value":"clone-produ-6a8d4","abId":"491f81be"},"ppv4l-produ-bec64":{"value":"clone-produ-eb097","abId":"491f81be"},"books-produ-1bfce":{"value":"clone-produ-d2dce","abId":"491f81be"},"ppv4t-produ-p0002":{"value":"clone-produ-7a0b3","abId":"491f81be"},"elect-produ-5c6db":{"value":"clone-produ-28f26","abId":"491f81be"},"testb-produ-7d489":{"value":"clone-produ-3dff6","abId":"491f81be"},"foodn-produ-1fa7d":{"value":"clone-produ-c3c45","abId":"491f81be"},"ppv4l-produ-3aca2":{"value":"clone-produ-ddad5","abId":"491f81be"},"ppv4l-produ-4f710":{"value":"clone-produ-d0fd9","abId":"491f81be"},"sport-produ-67d3b":{"value":"clone-produ-b4924","abId":"491f81be"},"ppv4t-produ-s0000":{"value":"clone-produ-714c9","abId":"491f81be"},"autom-produ-54f3e":{"value":"clone-produ-4b2b6","abId":"491f81be"},"lifes-produ-54e3e":{"value":"clone-produ-50430","abId":"491f81be"},"newgr-produ-b442f":{"value":"clone-produ-deeec","abId":"491f81be"},"elect-produ-a5164":{"value":"clone-produ-20480","abId":"491f81be"},"newap-homep-d9b50":{"value":"newap-homep-d1ed4","abId":"8ca3ad43"},"newap-homep-55db3":{"value":"newap-homep-78172","abId":"8ca3ad43"},"rankingBucket":{"value":"context_callout","abId":"942dfbf1"},"ncfv2DisabledAB":{"value":true,"abId":"eb46ccc1"}},"activateVip":{"asyncStatus":"INIT","widget":[]},"autosuggest":{"query":null,"payloadId":null,"searchHistory":[],"asyncStatus":"INIT","words":{},"searchBrowseHistoryRequest":{}},"basket":{"asyncStatus":"INIT","pageLevelError":false},"buyingGuides":{},"cartData":{"asyncStatus":"INIT","pageLevelError":false},"saveForLaterData":{"asyncStatus":"INIT","data":{"requestedStores":[]}},"checkoutPage":{"summary":{"asyncStatus":"INIT"},"checkoutAsyncStatus":"INIT","addressCache":{"newAddressForm":{"id":"newAddressForm","name":"","addressLine1":"","addressLine2":"","landmark":"","city":"","state":"","pincode":"","phone":"","alternatePhone":"","locationTypeTag":""}},"visualState":{"login":"EXPANDED","address":"COLLAPSED","orderSummary":"COLLAPSED","payment":"COLLAPSED"},"loginState":{"asyncStatus":"INIT"},"buyNow":{"eids":"","domain":"physical","analytics":{},"quantity":0},"addressLocation":{"asyncStatus":"INIT"},"staticPage":{"asyncStatus":"INIT"}},"claimedReward":{"asyncStatus":"INIT","widget":[]},"compareAddProductData":{"asyncStatus":"INIT","brandvsproduct":{},"brand":null},"compareBrandData":{"asyncStatus":"INIT"},"comparePageData":{"asyncStatus":"INIT","showDifference":false},"compareWidgetData":[],"config":{"asyncStatus":"SUCCESS","data":{"tooltip_zion":{"deliveryCharge":"## Shipping Charges For Non Flipkart Assured Items\n\n Shipping charges are calculated based on the number of units, distance and delivery date.\n\n For Plus as well as Non-Plus customers, Seller will decide shipping charges for all non-FAssured items.","deliverdBy":"## Shipping Charges For Flipkart Assured Items\n\n Shipping charges are calculated based on the number of units, distance and delivery date. \n\n For Plus customers, shipping charges  ...
#   </script>
#   <script nonce="10680836730608612107">
#    window.__BUNDLE_IDS__ = {};
#   </script>
#   <script nonce="10680836730608612107">
#    window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;
#
# 	if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }
#   </script>
#   <script async="" defer="" id="omni_script" nonce="10680836730608612107" src="//img1a.flixcart.com/www/linchpin/batman-returns/omni/omni16.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Getting Values from Html

# %% [markdown]
# Getting the names of all the mobile phones shown in the category (with tags).

# %%
names = soup.find_all('div',class_="_3wU53n")
names
# Out:
# [<div class="_3wU53n">Samsung Galaxy M31 (Ocean Blue, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M01 (Blue, 32 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M21 (Raven Black, 64 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M11 (Metallic Blue, 32 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A21s (Black, 64 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A21s (Blue, 64 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A31 (Prism Crush Black, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A51 (Prism Crush Blue, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A51 (Prism Crush Black, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A21s (White, 64 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A51 (Prism Crush White, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M11 (Violet, 32 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A51 (Prism Crush Blue, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A51 (Prism Crush Black, 128 GB)</div>,
#  <div class="_3wU53n">Samsung M01 core (Blue, 16 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M11 (Metallic Blue, 64 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A71 (Haze Crush Silver, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A10s (Black, 32 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M01 (Black, 32 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A31 (Prism Crush White, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy A31 (Prism Crush Blue, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M31 (Space Black, 128 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M21 (Midnight Blue, 64 GB)</div>,
#  <div class="_3wU53n">Samsung Galaxy M31 (Ocean Blue, 64 GB)</div>]

# %% [markdown]
# Selecting the text values and storing them in a list (excluding tags).

# %%
name = []
for i in range(0,len(names)):
    name.append(names[i].get_text())
name
# Out:
# ['Samsung Galaxy M31 (Ocean Blue, 128 GB)',
#  'Samsung Galaxy M01 (Blue, 32 GB)',
#  'Samsung Galaxy M21 (Raven Black, 64 GB)',
#  'Samsung Galaxy M11 (Metallic Blue, 32 GB)',
#  'Samsung Galaxy A21s (Black, 64 GB)',
#  'Samsung Galaxy A21s (Blue, 64 GB)',
#  'Samsung Galaxy A31 (Prism Crush Black, 128 GB)',
#  'Samsung Galaxy A51 (Prism Crush Blue, 128 GB)',
#  'Samsung Galaxy A51 (Prism Crush Black, 128 GB)',
#  'Samsung Galaxy A21s (White, 64 GB)',
#  'Samsung Galaxy A51 (Prism Crush White, 128 GB)',
#  'Samsung Galaxy M11 (Violet, 32 GB)',
#  'Samsung Galaxy A51 (Prism Crush Blue, 128 GB)',
#  'Samsung Galaxy A51 (Prism Crush Black, 128 GB)',
#  'Samsung M01 core (Blue, 16 GB)',
#  'Samsung Galaxy M11 (Metallic Blue, 64 GB)',
#  'Samsung Galaxy A71 (Haze Crush Silver, 128 GB)',
#  'Samsung Galaxy A10s (Black, 32 GB)',
#  'Samsung Galaxy M01 (Black, 32 GB)',
#  'Samsung Galaxy A31 (Prism Crush White, 128 GB)',
#  'Samsung Galaxy A31 (Prism Crush Blue, 128 GB)',
#  'Samsung Galaxy M31 (Space Black, 128 GB)',
#  'Samsung Galaxy M21 (Midnight Blue, 64 GB)',
#  'Samsung Galaxy M31 (Ocean Blue, 64 GB)']

# %% [markdown]
# Getting the prices of all the mobile phones shown in the category (with tags).

# %%
cost = soup.find_all('div',class_="_1vC4OE _2rQ-NK")
cost
# Out:
# [<div class="_1vC4OE _2rQ-NK">₹19,276</div>,
#  <div class="_1vC4OE _2rQ-NK">₹8,935</div>,
#  <div class="_1vC4OE _2rQ-NK">₹15,488</div>,
#  <div class="_1vC4OE _2rQ-NK">₹11,378</div>,
#  <div class="_1vC4OE _2rQ-NK">₹14,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹14,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹20,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹25,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹25,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹14,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹25,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹11,329</div>,
#  <div class="_1vC4OE _2rQ-NK">₹23,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹23,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹6,139</div>,
#  <div class="_1vC4OE _2rQ-NK">₹14,250</div>,
#  <div class="_1vC4OE _2rQ-NK">₹30,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹10,888</div>,
#  <div class="_1vC4OE _2rQ-NK">₹8,920</div>,
#  <div class="_1vC4OE _2rQ-NK">₹20,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹20,999</div>,
#  <div class="_1vC4OE _2rQ-NK">₹19,260</div>,
#  <div class="_1vC4OE _2rQ-NK">₹15,873</div>,
#  <div class="_1vC4OE _2rQ-NK">₹18,653</div>]

# %% [markdown]
# Selecting the values and storing them in a list (excluding tags).

# %%
price = []
for i in range(0,len(cost)):
    price.append(cost[i].get_text())
price
# Out:
# ['₹19,276',
#  '₹8,935',
#  '₹15,488',
#  '₹11,378',
#  '₹14,999',
#  '₹14,999',
#  '₹20,999',
#  '₹25,999',
#  '₹25,999',
#  '₹14,999',
#  '₹25,999',
#  '₹11,329',
#  '₹23,999',
#  '₹23,999',
#  '₹6,139',
#  '₹14,250',
#  '₹30,999',
#  '₹10,888',
#  '₹8,920',
#  '₹20,999',
#  '₹20,999',
#  '₹19,260',
#  '₹15,873',
#  '₹18,653']

# %% [markdown]
# Removing the Rupee symbol from the values

# %%
price[:] = [values.lstrip('₹') for values in price]
price
# Out:
# ['19,276',
#  '8,935',
#  '15,488',
#  '11,378',
#  '14,999',
#  '14,999',
#  '20,999',
#  '25,999',
#  '25,999',
#  '14,999',
#  '25,999',
#  '11,329',
#  '23,999',
#  '23,999',
#  '6,139',
#  '14,250',
#  '30,999',
#  '10,888',
#  '8,920',
#  '20,999',
#  '20,999',
#  '19,260',
#  '15,873',
#  '18,653']

# %% [markdown]
# Getting the ratings of all the mobile phones shown in the category (with tags).

# %%
rating = soup.find_all("div",class_="hGSR34")
rating
# Out:
# [<div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.1<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 _1nLEql E_uFuv">1<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">4<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">5<img class="_2lQ_WZ" src="..."/></div>,
#  <div class="hGSR34 E_uFuv">4<img class="_2lQ_WZ" src="..."/></div>]

# %% [markdown]
# Selecting the values and storing them in a list (excluding tags)

# %%
ratings = []
for i in range(0,24):
    ratings.append(rating[i].get_text())
ratings
# Out:
# ['4.4',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.4',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.4']

# %% [markdown]
# Getting the features of all the mobile phones shown in the category (with tags).

# %%
details = soup.find_all("li",class_="tVe95H")
details
# Out:
# [<li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">64MP + 8MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">6000 mAh Battery</li>,
#  <li class="tVe95H">Samsung Exynos 9 Octa 9611 Processor</li>,
#  <li class="tVe95H">1 year</li>,
#  <li class="tVe95H">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">14.48 cm (5.7 inch) HD+ Display</li>,
#  <li class="tVe95H">13MP + 2MP | 5MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Qualcomm Snapdragon (SDM439) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 5MP | 20MP Front Camera</li>,
#  <li class="tVe95H">6000 mAh Battery</li>,
#  <li class="tVe95H"> Exynos 9611-Octa Core processor Processor</li>,
#  <li class="tVe95H">1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase</li>,
#  <li class="tVe95H">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) HD+ Display</li>,
#  <li class="tVe95H">13MP + 5MP + 2MP | 8MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Qualcomm Snapdragon (SDM450-F01) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.51 cm (6.5 inch) HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 2MP + 2MP | 13MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 850 Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.51 cm (6.5 inch) HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 2MP + 2MP | 13MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 850 Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 5MP + 5MP | 20MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">MediaTek (MT6768) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">8 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 12MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 9611 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">8 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 12MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 9611 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.51 cm (6.5 inch) HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 2MP + 2MP | 13MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 850 Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">8 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 12MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 9611 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) HD+ Display</li>,
#  <li class="tVe95H">13MP + 5MP + 2MP | 8MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Qualcomm Snapdragon (SDM450-F01) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 12MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 9611 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 12MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Exynos 9611 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">1 GB RAM | 16 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">13.46 cm (5.3 inch) Full HD+ Display</li>,
#  <li class="tVe95H">8MP Rear Camera | 5MP Front Camera</li>,
#  <li class="tVe95H">3000 mAh Battery</li>,
#  <li class="tVe95H">MediaTek | MT6739WW quad core  Processor</li>,
#  <li class="tVe95H">1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase</li>,
#  <li class="tVe95H">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) HD+ Display</li>,
#  <li class="tVe95H">13MP + 5MP + 2MP | 8MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Qualcomm Snapdragon (SDM450-F01) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">8 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">17.02 cm (6.7 inch) Full HD+ Display</li>,
#  <li class="tVe95H">64MP + 12MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">4500 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Qualcomm SM7150 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">15.75 cm (6.2 inch) HD+ Display</li>,
#  <li class="tVe95H">13MP + 2MP | 8MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">MediaTek MT6762 Processor</li>,
#  <li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="tVe95H">3 GB RAM | 32 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">14.48 cm (5.7 inch) HD+ Display</li>,
#  <li class="tVe95H">13MP + 2MP | 5MP Front Camera</li>,
#  <li class="tVe95H">4000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">Qualcomm Snapdragon (SDM439) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 5MP + 5MP | 20MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">MediaTek (MT6768) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 5MP + 5MP | 20MP Front Camera</li>,
#  <li class="tVe95H">5000 mAh Lithium-ion Battery</li>,
#  <li class="tVe95H">MediaTek (MT6768) Octa Core Processor</li>,
#  <li class="tVe95H">1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories</li>,
#  <li class="tVe95H">6 GB RAM | 128 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">64MP + 8MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">6000 mAh Battery</li>,
#  <li class="tVe95H">Samsung Exynos 9 Octa 9611 Processor</li>,
#  <li class="tVe95H">1 year</li>,
#  <li class="tVe95H">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">48MP + 8MP + 5MP | 20MP Front Camera</li>,
#  <li class="tVe95H">6000 mAh Battery</li>,
#  <li class="tVe95H"> Exynos 9611-Octa Core processor Processor</li>,
#  <li class="tVe95H">1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase</li>,
#  <li class="tVe95H">6 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="tVe95H">16.26 cm (6.4 inch) Full HD+ Display</li>,
#  <li class="tVe95H">64MP + 8MP + 5MP + 5MP | 32MP Front Camera</li>,
#  <li class="tVe95H">6000 mAh Battery</li>,
#  <li class="tVe95H">Samsung Exynos 9 Octa 9611 Processor</li>,
#  <li class="tVe95H">1 year</li>]

# %% [markdown]
# Selecting the values and storing each kind of feature in a seperate list (excluding tags)

# %%
memory = []
display = []
camera = []
battery = []
processor = []
warranty = []
for i in range(0,len(details)):
    if (i%6==0):
        memory.append(details[i].get_text())
    elif (i%6==1):
        display.append(details[i].get_text())
    elif (i%6==2):
        camera.append(details[i].get_text())
    elif (i%6==3):
        battery.append(details[i].get_text())
    elif (i%6==4):
        processor.append(details[i].get_text())
    else:
        warranty.append(details[i].get_text())

# %% [markdown]
# Printing the lists containing various features

# %%
print(memory)
print('\n')
print(display)
print('\n')
print(camera)
print('\n')
print(battery)
print('\n')
print(processor)
print('\n')
print(warranty)
# Out:
# ['6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '8 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '8 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '8 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '1 GB RAM | 16 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '8 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 128 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '6 GB RAM | 64 GB ROM | Expandable Upto 512 GB']
#
#
# ['16.26 cm (6.4 inch) Full HD+ Display', '14.48 cm (5.7 inch) HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '13.46 cm (5.3 inch) Full HD+ Display', '16.26 cm (6.4 inch) HD+ Display', '17.02 cm (6.7 inch) Full HD+ Display', '15.75 cm (6.2 inch) HD+ Display', '14.48 cm (5.7 inch) HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display', '16.26 cm (6.4 inch) Full HD+ Display']
#
#
# ['64MP + 8MP + 5MP + 5MP | 32MP Front Camera', '13MP + 2MP | 5MP Front Camera', '48MP + 8MP + 5MP | 20MP Front Camera', '13MP + 5MP + 2MP | 8MP Front Camera', '48MP + 8MP + 2MP + 2MP | 13MP Front Camera', '48MP + 8MP + 2MP + 2MP | 13MP Front Camera', '48MP + 8MP + 5MP + 5MP | 20MP Front Camera', '48MP + 12MP + 5MP + 5MP | 32MP Front Camera', '48MP + 12MP + 5MP + 5MP | 32MP Front Camera', '48MP + 8MP + 2MP + 2MP | 13MP Front Camera', '48MP + 12MP + 5MP + 5MP | 32MP Front Camera', '13MP + 5MP + 2MP | 8MP Front Camera', '48MP + 12MP + 5MP + 5MP | 32MP Front Camera', '48MP + 12MP + 5MP + 5MP | 32MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '13MP + 5MP + 2MP | 8MP Front Camera', '64MP + 12MP + 5MP + 5MP | 32MP Front Camera', '13MP + 2MP | 8MP Front Camera', '13MP + 2MP | 5MP Front Camera', '48MP + 8MP + 5MP + 5MP | 20MP Front Camera', '48MP + 8MP + 5MP + 5MP | 20MP Front Camera', '64MP + 8MP + 5MP + 5MP | 32MP Front Camera', '48MP + 8MP + 5MP | 20MP Front Camera', '64MP + 8MP + 5MP + 5MP | 32MP Front Camera']
#
#
# ['6000 mAh Battery', '4000 mAh Lithium-ion Battery', '6000 mAh Battery', '5000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '3000 mAh Battery', '5000 mAh Lithium-ion Battery', '4500 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '4000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '5000 mAh Lithium-ion Battery', '6000 mAh Battery', '6000 mAh Battery', '6000 mAh Battery']
#
#
# ['Samsung Exynos 9 Octa 9611 Processor', 'Qualcomm Snapdragon (SDM439) Octa Core Processor', '\xa0Exynos 9611-Octa Core processor Processor', 'Qualcomm Snapdragon (SDM450-F01) Octa Core Processor', 'Exynos 850 Octa Core Processor', 'Exynos 850 Octa Core Processor', 'MediaTek (MT6768) Octa Core Processor', 'Exynos 9611 Processor', 'Exynos 9611 Processor', 'Exynos 850 Octa Core Processor', 'Exynos 9611 Processor', 'Qualcomm Snapdragon (SDM450-F01) Octa Core Processor', 'Exynos 9611 Processor', 'Exynos 9611 Processor', 'MediaTek | MT6739WW quad core\xa0 Processor', 'Qualcomm Snapdragon (SDM450-F01) Octa Core Processor', 'Qualcomm SM7150 Processor', 'MediaTek MT6762 Processor', 'Qualcomm Snapdragon (SDM439) Octa Core Processor', 'MediaTek (MT6768) Octa Core Processor', 'MediaTek (MT6768) Octa Core Processor', 'Samsung Exynos 9 Octa 9611 Processor', '\xa0Exynos 9611-Octa Core processor Processor', 'Samsung Exynos 9 Octa 9611 Processor']
#
#
# ['1 year', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', '1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', 'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for in the Box Accessories', '1 year', '1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase', '1 year']

# %% [markdown]
# ### Saving the data to DataFrame

# %% [markdown]
# Creating a dataframe to arrange the data collected

# %%
df = pd.DataFrame()

# %% [markdown]
# Creating columns in the dataframe for each list and viewing the list

# %%
df["Name"] = name
df["Price(₹)"] = price
df["Rating"] = ratings
df["Memory"] = memory 
df["Display"] = display
df["Camera"] = camera
df["Battery"] = battery
df["Processor"] = processor
df["Warranty"] = warranty
df
# Out:
#                                               Name   Price Rating  \
# 0          Samsung Galaxy M31 (Ocean Blue, 128 GB)  19,276    4.4
# 1                 Samsung Galaxy M01 (Blue, 32 GB)   8,935    4.2
# 2          Samsung Galaxy M21 (Raven Black, 64 GB)  15,488    4.4
# 3        Samsung Galaxy M11 (Metallic Blue, 32 GB)  11,378    4.2
# 4               Samsung Galaxy A21s (Black, 64 GB)  14,999    4.2
# 5                Samsung Galaxy A21s (Blue, 64 GB)  14,999    4.2
# 6   Samsung Galaxy A31 (Prism Crush Black, 128 GB)  20,999    4.3
# 7    Samsung Galaxy A51 (Prism Crush Blue, 128 GB)  25,999    4.4
# 8   Samsung Galaxy A51 (Prism Crush Black, 128 GB)  25,999    4.4
# 9               Samsung Galaxy A21s (White, 64 GB)  14,999    4.2
# 10  Samsung Galaxy A51 (Prism Crush White, 128 GB)  25,999    4.4
# 11              Samsung Galaxy M11 (Violet, 32 GB)  11,329    4.2
# 12   Samsung Galaxy A51 (Prism Crush Blue, 128 GB)  23,999    4.4
# 13  Samsung Galaxy A51 (Prism Crush Black, 128 GB)  23,999    4.4
# 14                  Samsung M01 core (Blue, 16 GB)   6,139    4.1
# 15       Samsung Galaxy M11 (Metallic Blue, 64 GB)  14,250    4.2
# 16  Samsung Galaxy A71 (Haze Crush Silver, 128 GB)  30,999    4.4
# 17              Samsung Galaxy A10s (Black, 32 GB)  10,888    4.3
# 18               Samsung Galaxy M01 (Black, 32 GB)   8,920    4.2
# 19  Samsung Galaxy A31 (Prism Crush White, 128 GB)  20,999    4.3
# 20   Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  20,999    4.3
# 21        Samsung Galaxy M31 (Space Black, 128 GB)  19,260    4.4
# 22       Samsung Galaxy M21 (Midnight Blue, 64 GB)  15,873    4.4
# 23          Samsung Galaxy M31 (Ocean Blue, 64 GB)  18,653    4.4
#
#                                             Memory  \
# 0   6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 1    3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 3    3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# 4    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 5    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 7   8 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 8   8 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 9    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 10  8 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 11   3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# 12  6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 13  6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 14   1 GB RAM | 16 GB ROM | Expandable Upto 512 GB
# 15   4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 16  8 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 17   3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# 18   3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# 19  6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 20  6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 21  6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 22   4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 23   6 GB RAM | 64 GB ROM | Expandable Upto 512 GB
#
#                                  Display  \
# 0   16.26 cm (6.4 inch) Full HD+ Display
# 1        14.48 cm (5.7 inch) HD+ Display
# 2   16.26 cm (6.4 inch) Full HD+ Display
# 3        16.26 cm (6.4 inch) HD+ Display
# 4        16.51 cm (6.5 inch) HD+ Display
# 5        16.51 cm (6.5 inch) HD+ Display
# 6   16.26 cm (6.4 inch) Full HD+ Display
# 7   16.26 cm (6.4 inch) Full HD+ Display
# 8   16.26 cm (6.4 inch) Full HD+ Display
# 9        16.51 cm (6.5 inch) HD+ Display
# 10  16.26 cm (6.4 inch) Full HD+ Display
# 11       16.26 cm (6.4 inch) HD+ Display
# 12  16.26 cm (6.4 inch) Full HD+ Display
# 13  16.26 cm (6.4 inch) Full HD+ Display
# 14  13.46 cm (5.3 inch) Full HD+ Display
# 15       16.26 cm (6.4 inch) HD+ Display
# 16  17.02 cm (6.7 inch) Full HD+ Display
# 17       15.75 cm (6.2 inch) HD+ Display
# 18       14.48 cm (5.7 inch) HD+ Display
# 19  16.26 cm (6.4 inch) Full HD+ Display
# 20  16.26 cm (6.4 inch) Full HD+ Display
# 21  16.26 cm (6.4 inch) Full HD+ Display
# 22  16.26 cm (6.4 inch) Full HD+ Display
# 23  16.26 cm (6.4 inch) Full HD+ Display
#
#                                          Camera                       Battery  \
# 0    64MP + 8MP + 5MP + 5MP | 32MP Front Camera              6000 mAh Battery
# 1                 13MP + 2MP | 5MP Front Camera  4000 mAh Lithium-ion Battery
# 2          48MP + 8MP + 5MP | 20MP Front Camera              6000 mAh Battery
# 3           13MP + 5MP + 2MP | 8MP Front Camera  5000 mAh Lithium-ion Battery
# 4    48MP + 8MP + 2MP + 2MP | 13MP Front Camera  5000 mAh Lithium-ion Battery
# 5    48MP + 8MP + 2MP + 2MP | 13MP Front Camera  5000 mAh Lithium-ion Battery
# 6    48MP + 8MP + 5MP + 5MP | 20MP Front Camera  5000 mAh Lithium-ion Battery
# 7   48MP + 12MP + 5MP + 5MP | 32MP Front Camera  4000 mAh Lithium-ion Battery
# 8   48MP + 12MP + 5MP + 5MP | 32MP Front Camera  4000 mAh Lithium-ion Battery
# 9    48MP + 8MP + 2MP + 2MP | 13MP Front Camera  5000 mAh Lithium-ion Battery
# 10  48MP + 12MP + 5MP + 5MP | 32MP Front Camera  4000 mAh Lithium-ion Battery
# 11          13MP + 5MP + 2MP | 8MP Front Camera  5000 mAh Lithium-ion Battery
# 12  48MP + 12MP + 5MP + 5MP | 32MP Front Camera  4000 mAh Lithium-ion Battery
# 13  48MP + 12MP + 5MP + 5MP | 32MP Front Camera  4000 mAh Lithium-ion Battery
# 14           8MP Rear Camera | 5MP Front Camera              3000 mAh Battery
# 15          13MP + 5MP + 2MP | 8MP Front Camera  5000 mAh Lithium-ion Battery
# 16  64MP + 12MP + 5MP + 5MP | 32MP Front Camera  4500 mAh Lithium-ion Battery
# 17                13MP + 2MP | 8MP Front Camera  4000 mAh Lithium-ion Battery
# 18                13MP + 2MP | 5MP Front Camera  4000 mAh Lithium-ion Battery
# 19   48MP + 8MP + 5MP + 5MP | 20MP Front Camera  5000 mAh Lithium-ion Battery
# 20   48MP + 8MP + 5MP + 5MP | 20MP Front Camera  5000 mAh Lithium-ion Battery
# 21   64MP + 8MP + 5MP + 5MP | 32MP Front Camera              6000 mAh Battery
# 22         48MP + 8MP + 5MP | 20MP Front Camera              6000 mAh Battery
# 23   64MP + 8MP + 5MP + 5MP | 32MP Front Camera              6000 mAh Battery
#
#                                             Processor  \
# 0                Samsung Exynos 9 Octa 9611 Processor
# 1    Qualcomm Snapdragon (SDM439) Octa Core Processor
# 2           Exynos 9611-Octa Core processor Processor
# 3   Qualcomm Snapdragon (SDM450-F01) Octa Core Pro...
# 4                      Exynos 850 Octa Core Processor
# 5                      Exynos 850 Octa Core Processor
# 6               MediaTek (MT6768) Octa Core Processor
# 7                               Exynos 9611 Processor
# 8                               Exynos 9611 Processor
# 9                      Exynos 850 Octa Core Processor
# 10                              Exynos 9611 Processor
# 11  Qualcomm Snapdragon (SDM450-F01) Octa Core Pro...
# 12                              Exynos 9611 Processor
# 13                              Exynos 9611 Processor
# 14           MediaTek | MT6739WW quad core  Processor
# 15  Qualcomm Snapdragon (SDM450-F01) Octa Core Pro...
# 16                          Qualcomm SM7150 Processor
# 17                          MediaTek MT6762 Processor
# 18   Qualcomm Snapdragon (SDM439) Octa Core Processor
# 19              MediaTek (MT6768) Octa Core Processor
# 20              MediaTek (MT6768) Octa Core Processor
# 21               Samsung Exynos 9 Octa 9611 Processor
# 22          Exynos 9611-Octa Core processor Processor
# 23               Samsung Exynos 9 Octa 9611 Processor
#
#                                              Warrenty
# 0                                              1 year
# 1   1 Year Manufacturer Warranty for Phone and 6 M...
# 2   1 year manufacturer warranty for device and 6 ...
# 3   1 Year Manufacturer Warranty for Phone and 6 M...
# 4   1 Year Manufacturer Warranty for Phone and 6 M...
# 5   1 Year Manufacturer Warranty for Phone and 6 M...
# 6   1 Year Manufacturer Warranty for Phone and 6 M...
# 7   Brand Warranty of 1 Year Available for Mobile ...
# 8   Brand Warranty of 1 Year Available for Mobile ...
# 9   1 Year Manufacturer Warranty for Phone and 6 M...
# 10  Brand Warranty of 1 Year Available for Mobile ...
# 11  1 Year Manufacturer Warranty for Phone and 6 M...
# 12  Brand Warranty of 1 Year Available for Mobile ...
# 13  Brand Warranty of 1 Year Available for Mobile ...
# 14  1 year manufacturer warranty for device and 6 ...
# 15  1 Year Manufacturer Warranty for Phone and 6 M...
# 16  Brand Warranty of 1 Year Available for Mobile ...
# 17  Brand Warranty of 1 Year Available for Mobile ...
# 18  1 Year Manufacturer Warranty for Phone and 6 M...
# 19  1 Year Manufacturer Warranty for Phone and 6 M...
# 20  1 Year Manufacturer Warranty for Phone and 6 M...
# 21                                             1 year
# 22  1 year manufacturer warranty for device and 6 ...
# 23                                             1 year

# %% [markdown]
# ### Converting to CSV

# %% [markdown]
# The dataframe is converted into a csv file in the specified location.

# %%
df.to_csv(r"C:\Users\My PC\Desktop\Samsung.csv",index=True)

# %% [markdown]
# Result : The .csv file is available in the specified location
